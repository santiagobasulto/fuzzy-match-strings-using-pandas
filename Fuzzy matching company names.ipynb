# %% [markdown]
# # Find repeated strings in different text files
#
# **The problem**: we have two text files containing names of companies. The problem is that the company names are sometimes spelled differently. For example, in one of them we have _"Western Digital"_ and in the other _"Western Digital Corp."_.
#
# We'll use Pandas to find those company names repeated and normalize them. We're also using an excellent Python library for string comparison: [fuzzywuzzy](https://github.com/seatgeek/fuzzywuzzy).

# %%
# !pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in /Users/santiagobasulto/.virtualenvs/ds-classes/lib/python3.6/site-packages
# You are using pip version 9.0.3, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import itertools
from fuzzywuzzy import fuzz, process
# Out:
# /Users/santiagobasulto/.virtualenvs/ds-classes/lib/python3.6/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# Read both files into its own DataFrame

# %%
df1 = pd.read_csv('test_CSV_1.csv')
df2 = pd.read_csv('test_CSV_2.csv')

# %% [markdown]
# Each file has 200/300 companies, not too large.

# %%
df1.size, df2.size
# Out:
# (266, 368)

# %% [markdown]
# And we can extract company names as regular np.arrays:

# %%
csv_1 = df1['CLIENT'].values
csv_2 = df2['Firm Name'].values

# %%
csv_1[:10]
# Out:
# array(['Adobe Systems, Inc.', 'Adventist Health', 'AECOM',
#        'Aerojet Rockedyne Holdings (GenCorp)',
#        'Alameda-Contra Costa Transit District',
#        'Alaska Community Foundation',
#        'Alaska Retirement Management Board', 'Alexander & Baldwin, Inc.',
#        'Allergan, Inc.', 'Alyeska Pipeline Service Company'], dtype=object)

# %%
csv_2[:10]
# Out:
# array(['AAA Northern California, Nevada & Utah Auto Exchange',
#        'ACCO Engineered Systems', 'Adams County Retirement Plan',
#        'Adidas America, Inc.', 'Adobe Systems, Inc.',
#        'Advanced Micro Devices, Inc.', 'AECOM Technology Corporation',
#        'Aera Energy LLC', 'Aerojet Rocketdyne Holdings, Inc.',
#        'Agilent Technologies, Inc.'], dtype=object)

# %% [markdown]
# In this example you can already notice repeated "similar" companies: `"AECOM"` in `csv_1` and `"AECOM Technology Corporation"` in `csv_2`.

# %% [markdown]
# To do our fuzzy comparison, we'll need to first build a "cartensian product" with all our companies. It'll be an "expensive" operation, and it'll create a big array with all the occurrences of `csv_2`, **per company in `csv_1`**. `csv_1` has 266 companies and `csv_2` has 368, the total will be: $266 * 368 = 97888$
#
# ![Cartesian product](https://upload.wikimedia.org/wikipedia/commons/thumb/4/4e/Cartesian_Product_qtl1.svg/440px-Cartesian_Product_qtl1.svg.png)

# %% [markdown]
# We create the cartesian product:

# %%
companies = list(itertools.product(csv_1, csv_2))

# %% [markdown]
# And as you can see we have 97888 companies:

# %%
len(companies)
# Out:
# 97888

# %%
df = pd.DataFrame(companies, columns=['CSV 1', 'CSV 2'])

# %% [markdown]
# This how our product looks like:

# %%
df.head()
# Out:
#                  CSV 1                                              CSV 2
# 0  Adobe Systems, Inc.  AAA Northern California, Nevada & Utah Auto Ex...
# 1  Adobe Systems, Inc.                            ACCO Engineered Systems
# 2  Adobe Systems, Inc.                       Adams County Retirement Plan
# 3  Adobe Systems, Inc.                               Adidas America, Inc.
# 4  Adobe Systems, Inc.                                Adobe Systems, Inc.

# %% [markdown]
# We'll now apply the `fuzz.partial_ratio` function from the `fuzzywuzzy` package (there are others, check [their docs](https://github.com/seatgeek/fuzzywuzzy))

# %%
df['Ratio Score'] = df.apply(lambda row: fuzz.partial_ratio(*row), axis=1)

# %% [markdown]
# And we have a score for reach occurrence:

# %%
df.head()
# Out:
#                  CSV 1                                              CSV 2  \
# 0  Adobe Systems, Inc.  AAA Northern California, Nevada & Utah Auto Ex...
# 1  Adobe Systems, Inc.                            ACCO Engineered Systems
# 2  Adobe Systems, Inc.                       Adams County Retirement Plan
# 3  Adobe Systems, Inc.                               Adidas America, Inc.
# 4  Adobe Systems, Inc.                                Adobe Systems, Inc.
#
#    Ratio Score
# 0           21
# 1           62
# 2           33
# 3           47
# 4          100

# %% [markdown]
# As you can see, _"Adobe"_ has a 100 score, which makes sense, what about _"AECOM"_?
#
# "AECOM" in csv_1 and "AECOM Technology Corporation" in c

# %%
df[(df['CSV 1'] == 'AECOM') & (df['CSV 2'] == "AECOM Technology Corporation")]
# Out:
#      CSV 1                         CSV 2  Ratio Score
# 742  AECOM  AECOM Technology Corporation          100

# %% [markdown]
# As you can see, it has a perfect score.
#
# Now we'll take a look at all those companies that provided a good match. I'll set our cutoff score to 90, you can try different values:

# %%
df[(df['Ratio Score'] > 90)]
# Out:
#                                                    CSV 1  \
# 4                                    Adobe Systems, Inc.
# 742                                                AECOM
# 1484               Alameda-Contra Costa Transit District
# 3697                                              Amazon
# 4435                                          Amgen Inc.
# 5175                                         Apple, Inc.
# 5544                                   Applied Materials
# 6286   Arizona Public Safety Personnel Retirement System
# 7023                     Arizona State Retirement System
# 8865                                Asante Health System
# 9234                                         ASARCO, LLC
# 9605   Automobile Club of Southern California (AAA of...
# 9974                                               Avaya
# 10343                         Avery Dennison Corporation
# 10712                                 Avista Corporation
# 11081                                              Avnet
# 11450                                   Ball Corporation
# 12189                                            Bechtel
# 12930                          Blue Shield of California
# 13299                                      Boise Cascade
# 15882                 California Institute of Technology
# 16252                            California Savings Plus
# 16621        California State Teachers Retirement System
# 16990                    California Teachers Association
# 18466                        Catholic Health Initiatives
# 18836                        Cedars-Sinai Medical Center
# 19573                                    CH2M HILL, Inc.
# 20678                                Chevron Corporation
# 22151                                Cisco Systems, Inc.
# 22898    City of San Jose Retirement Services Department
# ...                                                  ...
# 70187                       Sandia National Laboratories
# 70557                     Santa Barbara Cottage Hospital
# 70927                             Santa Clara University
# 71668                                     Scripps Health
# 72038                           Seagate Technology, Inc.
# 72407                        Seattle Children's Hospital
# 73146                                      Sempra Energy
# 73516                       Sharp HealthCare Corporation
# 74254                         Simpson Investment Company
# 75730                 Southern California Edison Company
# 76099                          Southwest Gas Corporation
# 76469                                  SRI International
# 77577                                Stanford University
# 77948                                          Starbucks
# 78318                                      Sutter Health
# 78687                               Symantec Corporation
# 79057                              Teledyne Technologies
# 79428                          The Aerospace Corporation
# 80166                           The California Endowment
# 83115          The Idaho Endowment Fund Investment Board
# 84220                          The Queens Health Systems
# 87166                                The Walt Disney Co.
# 88271                                  T-Mobile US, Inc.
# 92337            University of Southern California (USC)
# 93814                              Utah State University
# 94923                      Virginia Mason Medical Center
# 96033                                        Wells Fargo
# 96402                                    Western Digital
# 96771             Western Union Financial Services, Inc.
# 97141                               Weyerhaeuser Company
#
#                                                    CSV 2  Ratio Score
# 4                                    Adobe Systems, Inc.          100
# 742                         AECOM Technology Corporation          100
# 1484               Alameda-Contra Costa Transit District          100
# 3697                           Amazon.com Holdings, Inc.          100
# 4435                                          Amgen Inc.          100
# 5175                                         Apple, Inc.          100
# 5544                             Applied Materials, Inc.          100
# 6286   Arizona Public Safety Personnel Retirement System          100
# 7023                     Arizona State Retirement System          100
# 8865                 Asante Health System & Subsidiaries          100
# 9234                                         ASARCO, LLC          100
# 9605              Automobile Club of Southern California          100
# 9974                                          Avaya Inc.          100
# 10343                         Avery Dennison Corporation          100
# 10712                                 Avista Corporation          100
# 11081                                        Avnet, Inc.          100
# 11450                                   Ball Corporation          100
# 12189                                Bechtel Group, Inc.          100
# 12930                          Blue Shield of California          100
# 13299                         Boise Cascade Holdings LLC          100
# 15882                 California Institute of Technology          100
# 16252                    California Savings Plus Program          100
# 16621  California State Teachers Retirement System (C...          100
# 16990                    California Teachers Association          100
# 18466                        Catholic Health Initiatives          100
# 18836                        Cedars-Sinai Medical Center          100
# 19573                                    CH2M HILL, Inc.          100
# 20678                                Chevron Corporation          100
# 22151                                Cisco Systems, Inc.          100
# 22898    City of San Jose Retirement Services Department          100
# ...                                                  ...          ...
# 70187                       Sandia National Laboratories          100
# 70557                     Santa Barbara Cottage Hospital          100
# 70927                             Santa Clara University          100
# 71668                                     Scripps Health          100
# 72038                           Seagate Technology, Inc.          100
# 72407                        Seattle Children's Hospital          100
# 73146                                      Sempra Energy          100
# 73516                       Sharp HealthCare Corporation          100
# 74254                         Simpson Investment Company          100
# 75730                         Southern California Edison          100
# 76099                          Southwest Gas Corporation          100
# 76469                                  SRI International          100
# 77577                                Stanford University          100
# 77948                              Starbucks Corporation          100
# 78318                         Sutter Health & Affiliates          100
# 78687                               Symantec Corporation          100
# 79057                 Teledyne Technologies Incorporated          100
# 79428                          The Aerospace Corporation          100
# 80166                           The California Endowment          100
# 83115          The Idaho Endowment Fund Investment Board          100
# 84220                         The Queen's Health Systems           96
# 87166                                The Walt Disney Co.          100
# 88271                                  T-Mobile US, Inc.          100
# 92337                  University of Southern California          100
# 93814                              Utah State University          100
# 94923                      Virginia Mason Medical Center          100
# 96033                              Wells Fargo & Company          100
# 96402                              Western Digital Corp.          100
# 96771             Western Union Financial Services, Inc.          100
# 97141                               Weyerhaeuser Company          100
#
# [102 rows x 3 columns]

# %% [markdown]
# The problem we have here is that we still have repeated names with perfect matches, for example _"Apple, Inc."_ with _"Apple, Inc."_. We can obviate those:

# %%
df[(df['Ratio Score'] > 90) & (df['CSV 1'] != df['CSV 2'])]
# Out:
#                                                    CSV 1  \
# 742                                                AECOM
# 3697                                              Amazon
# 5544                                   Applied Materials
# 8865                                Asante Health System
# 9605   Automobile Club of Southern California (AAA of...
# 9974                                               Avaya
# 11081                                              Avnet
# 12189                                            Bechtel
# 13299                                      Boise Cascade
# 16252                            California Savings Plus
# 16621        California State Teachers Retirement System
# 25484  Contra Costa County Employees Retirement Assoc...
# 25617  Contra Costa County Employees Retirement Assoc...
# 25681  Contra Costa County Employees Retirement Assoc...
# 25858                                             Costco
# 26206  County of Los Angeles Deferred Compensation Pr...
# 28821          Dignity Health (Catholic Healthcare West)
# 32159                                            Fortive
# 35859  Great-West Life & Annuity Insurance Company/EM...
# 39189                                    Idaho Power Co.
# 41775                              Jack in the Box, Inc.
# 48067                                             Mattel
# 63526                                      Presbytherian
# 66859        Sacramento City Employees Retirement System
# 67596                                      Safeway, Inc.
# 75730                 Southern California Edison Company
# 77948                                          Starbucks
# 78318                                      Sutter Health
# 79057                              Teledyne Technologies
# 84220                          The Queens Health Systems
# 92337            University of Southern California (USC)
# 96033                                        Wells Fargo
# 96402                                    Western Digital
#
#                                                    CSV 2  Ratio Score
# 742                         AECOM Technology Corporation          100
# 3697                           Amazon.com Holdings, Inc.          100
# 5544                             Applied Materials, Inc.          100
# 8865                 Asante Health System & Subsidiaries          100
# 9605              Automobile Club of Southern California          100
# 9974                                          Avaya Inc.          100
# 11081                                        Avnet, Inc.          100
# 12189                                Bechtel Group, Inc.          100
# 13299                         Boise Cascade Holdings LLC          100
# 16252                    California Savings Plus Program          100
# 16621  California State Teachers Retirement System (C...          100
# 25484                                Contra Costa County          100
# 25617      Marin County Employees Retirement Association           91
# 25681     Sonoma County Employees Retirement Association           91
# 25858                       Costco Wholesale Corporation          100
# 26206          City of Los Angeles Deferred Compensation           95
# 28821                                     Dignity Health          100
# 32159                                Fortive Corporation          100
# 35859        Great-West Life & Annuity Insurance Company          100
# 39189                                Idaho Power Company           93
# 41775                               Jack in the Box Inc.           95
# 48067                                       Mattel, Inc.          100
# 63526                   Presbyterian Healthcare Services           92
# 66859      Sacramento County Employees Retirement System           93
# 67596                                       Safeway Inc.           92
# 75730                         Southern California Edison          100
# 77948                              Starbucks Corporation          100
# 78318                         Sutter Health & Affiliates          100
# 79057                 Teledyne Technologies Incorporated          100
# 84220                         The Queen's Health Systems           96
# 92337                  University of Southern California          100
# 96033                              Wells Fargo & Company          100
# 96402                              Western Digital Corp.          100

# %% [markdown]
# And now it looks much better 😊, check a few occurrences, for example `"Wells Fargo" | "Wells Fargo & Company"` or `"Western Digital" | "Western Digital Corp."`

# %% [markdown]
# Finally, we can export our results to Excel if you prefer to use spreadsheets instead of Python (for now 😉):

# %%
df.to_excel('output.xlsx')
